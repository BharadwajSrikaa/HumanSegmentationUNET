# %%
import tensorflow as tf
import numpy as np
import os
from skimage.io import imread,imshow
from skimage.transform import resize
from skimage import color
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split

# %%
IMG_HEIGHT = 256
IMG_WIDTH  = 256
CHANNELS = 3


training_images_names = os.listdir('/content/drive/MyDrive/UNET Architecture/data/Training_Images')
training_masks_names = os.listdir('/content/drive/MyDrive/UNET Architecture/data/masks')

X = np.zeros((len(training_images_names),IMG_HEIGHT,IMG_WIDTH,CHANNELS),dtype='uint8')
y = np.zeros((len(training_masks_names),IMG_HEIGHT,IMG_WIDTH,1))

# %%
for i,n in enumerate(training_images_names):
    img = imread(f'/content/drive/MyDrive/UNET Architecture/data/Training_Images/{n}')
    img = resize(img,(IMG_HEIGHT,IMG_WIDTH,CHANNELS),mode='constant',preserve_range=True)
    fn = str(n.split('.')[0]) + '.png'
    mask = imread(f'/content/drive/MyDrive/UNET Architecture/data/masks/{fn}')
    mask = resize(mask,(IMG_HEIGHT,IMG_WIDTH,1),mode='constant')

    X[i] = img
    y[i] = mask

X[0].shape

# %%
i = np.random.randint(0,len(X))
fig,(a1,a2)=plt.subplots(1,2)
a1.imshow(X[i])
a2.imshow(y[i].reshape(y[i].shape[:-1]),cmap='gray')

# %%
#building U-Net

inputs = tf.keras.layers.Input((IMG_HEIGHT,IMG_WIDTH,CHANNELS))
s = tf.keras.layers.Lambda(lambda x:x/255)(inputs)

#contracting path
c1 = tf.keras.layers.Conv2D(16,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)


c2 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)


c3 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)


c4 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)


c5 = tf.keras.layers.Conv2D(256,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5_1 = tf.keras.layers.Conv2D(256,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(c5)
c5_1 = tf.keras.layers.Dropout(0.3)(c5_1)
c5_2 = tf.keras.layers.Conv2D(256,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(c5_1)
c5_3 = tf.keras.layers.Conv2D(256,(3,3),activation='relu',kernel_initializer='he_normal',padding='same',dilation_rate=2)(c5_2)
c5_4 = tf.keras.layers.Conv2D(512,(3,3),activation='relu',kernel_initializer='he_normal',padding='same',dilation_rate=2)(c5_3 )
c5_5 = tf.keras.layers.concatenate([c5_1,c5_4])


#expanding path
u4 = tf.keras.layers.Conv2DTranspose(128,(2,2),strides=(2,2),padding='same')(c5_5)
u4 = tf.keras.layers.concatenate([u4,c4])
u4 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u4)
u4 = tf.keras.layers.Dropout(0.2)(u4)
u4 = tf.keras.layers.Conv2D(128,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u4)


u3 = tf.keras.layers.Conv2DTranspose(64,(2,2),strides=(2,2),padding='same')(u4)
u3 = tf.keras.layers.concatenate([u3,c3])
u3 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u3)
u3 = tf.keras.layers.Dropout(0.2)(u3)
u3 = tf.keras.layers.Conv2D(64,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u3)


u2 = tf.keras.layers.Conv2DTranspose(32,(2,2),strides=(2,2),padding='same')(u3)
u2 = tf.keras.layers.concatenate([u2,c2])
u2 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u2)
u2 = tf.keras.layers.Dropout(0.2)(u2)
u2 = tf.keras.layers.Conv2D(32,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u2)


u1 = tf.keras.layers.Conv2DTranspose(16,(2,2),strides=(2,2),padding='same')(u2)
u1 = tf.keras.layers.concatenate([u1,c1])
u1 = tf.keras.layers.Conv2D(16,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u1)
u1 = tf.keras.layers.Dropout(0.2)(u1)
u1 = tf.keras.layers.Conv2D(16,(3,3),activation='relu',kernel_initializer='he_normal',padding='same')(u1)

output = tf.keras.layers.Conv2D(1,(1,1),activation='sigmoid')(u1)

model = tf.keras.Model(inputs=[inputs],outputs=[output])
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  lambda (Lambda)             (None, 256, 256, 3)          0         ['input_1[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['lambda[0][0]']
#
#  dropout (Dropout)           (None, 256, 256, 16)         0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 32, 32, 128)          0         ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 128)          147584    ['dropout_3[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 128)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 256)          295168    ['max_pooling2d_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 16, 16, 256)          0         ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 256)          590080    ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 16, 16, 256)          0         ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)          590080    ['dropout_5[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 256)          590080    ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 512)          1180160   ['conv2d_11[0][0]']
#
#  concatenate (Concatenate)   (None, 16, 16, 768)          0         ['dropout_5[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 128)          393344    ['concatenate[0][0]']
#  anspose)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 256)          0         ['conv2d_transpose[0][0]',
#  )                                                                   'conv2d_7[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 32, 32, 128)          0         ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_6[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 64)           32832     ['conv2d_14[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_2[0][0]']
#
#  dropout_7 (Dropout)         (None, 64, 64, 64)           0         ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_7[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 32)         8224      ['conv2d_16[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)         (None, 128, 128, 32)         0         ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_8[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 256, 256, 16)         2064      ['conv2d_18[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_4[0][0]']
#
#  dropout_9 (Dropout)         (None, 256, 256, 16)         0         ['conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_9[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 256, 256, 1)          17        ['conv2d_20[0][0]']
#
# ==================================================================================================
# Total params: 4563569 (17.41 MB)
# Trainable params: 4563569 (17.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X,  y, test_size=0.1, random_state=42)

# %%
# TRAINING MODEL

results = model.fit(X_train,y_train,batch_size=16,epochs=100)
model.save('models/human_segmentation_non-aug_100_v2.h5')
# Out:
# Epoch 1/100
# 17/17 [==============================] - 204s 12s/step - loss: 0.6096 - accuracy: 0.6876
# Epoch 2/100
# 17/17 [==============================] - 194s 11s/step - loss: 0.5911 - accuracy: 0.7006
# Epoch 3/100
# 17/17 [==============================] - 194s 11s/step - loss: 0.5837 - accuracy: 0.7009
# Epoch 4/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.5774 - accuracy: 0.7010
# Epoch 5/100
# 17/17 [==============================] - 192s 11s/step - loss: 0.5721 - accuracy: 0.7013
# Epoch 6/100
# 17/17 [==============================] - 193s 11s/step - loss: 0.5247 - accuracy: 0.7065
# Epoch 7/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.5005 - accuracy: 0.7555
# Epoch 8/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.4744 - accuracy: 0.7609
# Epoch 9/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.4263 - accuracy: 0.7915
# Epoch 10/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.4241 - accuracy: 0.7967
# Epoch 11/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.3835 - accuracy: 0.8178
# Epoch 12/100
# 17/17 [==============================] - 198s 12s/step - loss: 0.3759 - accuracy: 0.8231
# Epoch 13/100
# 17/17 [==============================] - 200s 12s/step - loss: 0.3702 - accuracy: 0.8284
# Epoch 14/100
# 17/17 [==============================] - 200s 12s/step - loss: 0.3380 - accuracy: 0.8457
# Epoch 15/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.3143 - accuracy: 0.8551
# Epoch 16/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.3138 - accuracy: 0.8515
# Epoch 17/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.3013 - accuracy: 0.8587
# Epoch 18/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.2969 - accuracy: 0.8617
# Epoch 19/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.3023 - accuracy: 0.8581
# Epoch 20/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.2840 - accuracy: 0.8640
# Epoch 21/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.2793 - accuracy: 0.8672
# Epoch 22/100
# 17/17 [==============================] - 192s 11s/step - loss: 0.2665 - accuracy: 0.8730
# Epoch 23/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.2433 - accuracy: 0.8838
# Epoch 24/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.2319 - accuracy: 0.8876
# Epoch 25/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.2311 - accuracy: 0.8893
# Epoch 26/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.2171 - accuracy: 0.8943
# Epoch 27/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.2257 - accuracy: 0.8901
# Epoch 28/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.2066 - accuracy: 0.8995
# Epoch 29/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.2239 - accuracy: 0.8923
# Epoch 30/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.1992 - accuracy: 0.9002
# Epoch 31/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.1871 - accuracy: 0.9059
# Epoch 32/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.1975 - accuracy: 0.9027
# Epoch 33/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.1903 - accuracy: 0.9044
# Epoch 34/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.2081 - accuracy: 0.8960
# Epoch 35/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.1917 - accuracy: 0.9057
# Epoch 36/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.1711 - accuracy: 0.9129
# Epoch 37/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.1566 - accuracy: 0.9179
# Epoch 38/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.1445 - accuracy: 0.9248
# Epoch 39/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.1405 - accuracy: 0.9253
# Epoch 40/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.1441 - accuracy: 0.9236
# Epoch 41/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.1249 - accuracy: 0.9313
# Epoch 42/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.1354 - accuracy: 0.9264
# Epoch 43/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.1318 - accuracy: 0.9299
# Epoch 44/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.1275 - accuracy: 0.9319
# Epoch 45/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.1154 - accuracy: 0.9351
# Epoch 46/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.1191 - accuracy: 0.9345
# Epoch 47/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.1109 - accuracy: 0.9377
# Epoch 48/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.1020 - accuracy: 0.9409
# Epoch 49/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0987 - accuracy: 0.9426
# Epoch 50/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.0972 - accuracy: 0.9431
# Epoch 51/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0948 - accuracy: 0.9435
# Epoch 52/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0961 - accuracy: 0.9434
# Epoch 53/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.0938 - accuracy: 0.9437
# Epoch 54/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.0895 - accuracy: 0.9462
# Epoch 55/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0879 - accuracy: 0.9462
# Epoch 56/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0926 - accuracy: 0.9439
# Epoch 57/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0867 - accuracy: 0.9473
# Epoch 58/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.0761 - accuracy: 0.9513
# Epoch 59/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.0713 - accuracy: 0.9526
# Epoch 60/100
# 17/17 [==============================] - 196s 12s/step - loss: 0.0708 - accuracy: 0.9533
# Epoch 61/100
# 17/17 [==============================] - 201s 12s/step - loss: 0.0750 - accuracy: 0.9516
# Epoch 62/100
# 17/17 [==============================] - 195s 11s/step - loss: 0.0757 - accuracy: 0.9508
# Epoch 63/100
# 17/17 [==============================] - 193s 11s/step - loss: 0.0659 - accuracy: 0.9546
# Epoch 64/100
# 17/17 [==============================] - 195s 11s/step - loss: 0.0642 - accuracy: 0.9551
# Epoch 65/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.0621 - accuracy: 0.9560
# Epoch 66/100
# 17/17 [==============================] - 195s 11s/step - loss: 0.0616 - accuracy: 0.9563
# Epoch 67/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.0609 - accuracy: 0.9564
# Epoch 68/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0552 - accuracy: 0.9586
# Epoch 69/100
# 17/17 [==============================] - 191s 11s/step - loss: 0.0529 - accuracy: 0.9592
# Epoch 70/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.0496 - accuracy: 0.9603
# Epoch 71/100
# 17/17 [==============================] - 193s 11s/step - loss: 0.0499 - accuracy: 0.9602
# Epoch 72/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0525 - accuracy: 0.9592
# Epoch 73/100
# 17/17 [==============================] - 192s 11s/step - loss: 0.0539 - accuracy: 0.9587
# Epoch 74/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.0525 - accuracy: 0.9593
# Epoch 75/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.0504 - accuracy: 0.9600
# Epoch 76/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.0513 - accuracy: 0.9599
# Epoch 77/100
# 17/17 [==============================] - 196s 12s/step - loss: 0.0508 - accuracy: 0.9597
# Epoch 78/100
# 17/17 [==============================] - 198s 12s/step - loss: 0.0479 - accuracy: 0.9608
# Epoch 79/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0466 - accuracy: 0.9612
# Epoch 80/100
# 17/17 [==============================] - 190s 11s/step - loss: 0.0435 - accuracy: 0.9622
# Epoch 81/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.0412 - accuracy: 0.9632
# Epoch 82/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.0394 - accuracy: 0.9639
# Epoch 83/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0376 - accuracy: 0.9643
# Epoch 84/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.0394 - accuracy: 0.9637
# Epoch 85/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.0370 - accuracy: 0.9644
# Epoch 86/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0367 - accuracy: 0.9646
# Epoch 87/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.0469 - accuracy: 0.9612
# Epoch 88/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.0428 - accuracy: 0.9626
# Epoch 89/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0511 - accuracy: 0.9603
# Epoch 90/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0698 - accuracy: 0.9525
# Epoch 91/100
# 17/17 [==============================] - 184s 11s/step - loss: 0.0556 - accuracy: 0.9580
# Epoch 92/100
# 17/17 [==============================] - 189s 11s/step - loss: 0.0542 - accuracy: 0.9587
# Epoch 93/100
# 17/17 [==============================] - 185s 11s/step - loss: 0.0443 - accuracy: 0.9619
# Epoch 94/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0407 - accuracy: 0.9633
# Epoch 95/100
# 17/17 [==============================] - 188s 11s/step - loss: 0.0386 - accuracy: 0.9639
# Epoch 96/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0359 - accuracy: 0.9646
# Epoch 97/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.0338 - accuracy: 0.9653
# Epoch 98/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.0320 - accuracy: 0.9660
# Epoch 99/100
# 17/17 [==============================] - 187s 11s/step - loss: 0.0310 - accuracy: 0.9663
# Epoch 100/100
# 17/17 [==============================] - 186s 11s/step - loss: 0.0304 - accuracy: 0.9664
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model=
fig,(a1,a2) = plt.subplots(1,2,figsize=(17,8))
a1.plot(np.arange(0,100),results.history['loss'],label = 'loss')
a2.plot(np.arange(0,100),results.history['accuracy'],label='accuracy')
a1.legend()
a2.legend()
plt.savefig('losses_and_accuracies_100_v2.png')

# %%
k=np.random.randint(0,len(X_test))
fig,(a1,a2) = plt.subplots(1,2)

a1.imshow(X_test[k])

(h,w,c) = X_test[k].shape
i = X_test[k].reshape((1,h,w,c))

pred = model.predict(i)

a2.imshow(pred.reshape(pred.shape[1:-1]),cmap='gray')
# Out:
# 1/1 [==============================] - 0s 279ms/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
